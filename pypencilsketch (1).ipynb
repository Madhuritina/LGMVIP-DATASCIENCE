# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
photo = cv2.imread('/content/viratkohli.jpg')

# %%
import time
start = time.time()

# %% [markdown]
# #Internal Mechanism of Model

# %%
gray = cv2.cvtColor(photo, cv2.COLOR_BGR2GRAY)
from google.colab.patches import cv2_imshow
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=474x632 at 0x7FBB45844E80>

# %%
invert = cv2.bitwise_not(gray)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=474x632 at 0x7FBB550E47F0>

# %%
blur = cv2.GaussianBlur(invert, (15, 15), 0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=474x632 at 0x7FBB457D0C70>

# %%
invertblur = cv2.bitwise_not(blur)
cv2_imshow(invertblur)
# Out:
# <PIL.Image.Image image mode=L size=474x632 at 0x7FBB457D90D0>

# %%
sketch = cv2.divide(gray, invertblur, scale= 250.0)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=474x632 at 0x7FBB457D0C40>

# %%
from google.colab.patches import cv2_imshow
cv2.imwrite('output.png', sketch)
# Out:
# True

# %% [markdown]
# #For time taken calculation

# %%
end = time.time()
print(end-start)
# Out:
# 0.4620673656463623
